# %% [markdown]
# <a href="https://colab.research.google.com/github/antonnecajkin-jpg/Timeseries/blob/wwwwwwwww/www.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
for i in range(7):
  for j in range(i + 1):
    print('*', end='')
  print()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %% [markdown]
# <a href="https://colab.research.google.com/github/antonnecajkin-jpg/Timeseries/blob/ANTIARBA/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
n = int(input())
m = int(input())
if n % 2 != 0:
  for i in range(n, m - 1, -2):
    print(i)
else:

  for j in range(n - 1, m - 1, -2):
    print(j)
# Out:
# 6
# -2
# 5
# 3
# 1
# -1
